# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
import itertools
import re
import numpy as np
sns.set_style('white')

# %%
infile = '/home/harald/projects/somatic/test_samples/wes_cnvs/chr7_egfr.raw_read_depth.matrix_T.txt'
df = pd.read_table(infile, header = 0)

# %%
df.max()
# Out:
# position    64219723.0
# BTN-083          831.0
# BTN-091          687.0
# BTN-046          922.0
# BTN-070          699.0
# BTN-073          684.0
# BTN-092          737.0
# BTN-051          898.0
# BTN-075          751.0
# BTN-054          807.0
# BTN-089          717.0
# BTN-047          877.0
# BTN-050          576.0
# BTN-088          813.0
# BTN-084         1205.0
# BTN-069          849.0
# BTN-053          954.0
# BTN-042          677.0
# BTN-057          687.0
# BTN-044          824.0
# BTN-056         1137.0
# BTN-066          862.0
# BTN-086          626.0
# BTN-063          819.0
# BTN-081          641.0
# BTN-074          662.0
# BTN-034          680.0
# BTN-076          659.0
# BTN-059          993.0
# BTN-048          689.0
# BTN-068         1508.0
# BTN-079          830.0
# BTN-049          823.0
# BTN-060          666.0
# BTN-058          829.0
# BTN-040          712.0
# BTN-043         1091.0
# BTN-062         5230.0
# BTN-085          793.0
# BTN-061          789.0
# ...

# %%
fig, axes = plt.subplots(nrows=6,ncols=1,figsize=(10,20), sharey=True)
axes[0].plot(df['BTN-071'])
axes[1].plot(df['BTN-034'])
axes[2].plot(df['BTN-092'])
axes[3].plot(df['BTN-062'])
axes[4].plot(df['BTN-068'])
axes[5].plot(df['BTN-043'])

# %%
plt.plot(df['BTN-062'][120000:200000])
